# %%
#Registration form

# %%
print("Registration form")
# Out:
# Registration form

# %%
print("First name:\t")
# Out:
# First name:

# %%
f_name = input()
# Out:
#  Eric

# %%
print("Last name:\t")
# Out:
# Last name:

# %%
l_name = input()
# Out:
#  Idle

# %%
print("Birth year:\t")
# Out:
# Birth year:

# %%
birth_year = int(input())
# Out:
#  1934

# %%
birth_year_str = str(birth_year)

# %%
temp_pass = f_name + "*" + birth_year_str

# %%
print("\nWelcome " + f_name + " " + l_name + "!")
# Out:
# Welcome Eric Idle!

# %%
print("\nYour registration is complete.")
# Out:
# Your registration is complete!

# %%
print("\nYour temporary password is: " + temp_pass)
# Out:
# Your temporary password is: Eric*1934
