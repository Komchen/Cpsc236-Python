# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
champs={}

with open('world_cup_champions.txt', 'r') as f:
    ln = 0
    for line in f:
        ln +=1

        if ln==1:
            continue
        Wcup = line.strip().split(",")

        year = Wcup[0]
        country = Wcup[1]

        if country not in champs:
            champs[country] = []
        champs[country].append(year)

print("Country \t WINS \t Years")
print("==============================")

for country in sorted(champs):
    win = len(champs[country])
    years = ",".join(champs[country])

    print(f"{country:<15}{win:<8}{years}")
# Out:
# Country 	 WINS 	 Years
# ==============================
# Argentina      2       1978,1986
# Brazil         5       1958,1962,1970,1994,2002
# England        1       1966
# France         1       1998
# Germany        4       1954,1974,1990,2014
# Italy          4       1934,1938,1982,2006
# Spain          1       2010
# Uruguay        2       1930,1950

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 5,654.58
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
def menu():
    print("view\t -View sales for specified month")
    print("edit\t -Edit sales for specified month")
    print("totals\t -View sales summary for year")
    print("exit\t -Exit program")

def view(sale):
    month = input("Three letter month: ").strip().lower()
    if month in sale:
        print("\nSales amount for ",month, " is ", round(sale[month],2),".\n")
    else:
        print("invalid month")

def edit(sale):
    month = input("Three letter month: ").strip().lower()
    if month in sale:
        amount = float(input("Sales amount:"))
        sale[month] = amount
        print("\nSales amount for ",month, " is ", round(sale[month],2),".\n")
    else:
        print("invalid month")

def totals(sale):
    total = sum(sale.values())
    avg= total/len(sale)
    print("Yearly Total: ", round(total,2))
    print("Montly average: ", round(avg,2))

def file():
    sale ={} 
    with open('monthly_sales.txt','r') as f:
        for line in f:
            month, amount = line.strip().split("\t")
            sale[month.lower()] =float(amount)
    return sale
    
def save(sale):
    with open('monthly_sale.txt', 'w') as f:
                for month, amount in sale.items():
                    f.write(f"{month}\t{int(amount)}\n")
def main():
    sale = file()
    while True:
        menu()
        command = input("\nCommand: ").strip().lower()
        if command == 'view':
            view(sale)
        elif command == 'edit':
            edit(sale)
            save(sale)
        elif command == 'totals':
            totals(sale)
        elif command == 'exit':
            print("OKay bye bye!!!!!!!")
            break
        else:
            print("Invalid command")

if __name__ == '__main__':
    main()
# Out:
# view	 -View sales for specified month
# edit	 -Edit sales for specified month
# totals	 -View sales summary for year
# exit	 -Exit program
# Command:  view
# Three letter month:  jan
# Sales amount for  jan  is  14317.0 .
#
# view	 -View sales for specified month
# edit	 -Edit sales for specified month
# totals	 -View sales summary for year
# exit	 -Exit program
# Command:  edit
# Three letter month:  jan
# Sales amount: 15293
# Sales amount for  jan  is  15293.0 .
#
# view	 -View sales for specified month
# edit	 -Edit sales for specified month
# totals	 -View sales summary for year
# exit	 -Exit program
# Command:  totals
# Yearly Total:  67855.0
# Montly average:  5654.58
# view	 -View sales for specified month
# edit	 -Edit sales for specified month
# totals	 -View sales summary for year
# exit	 -Exit program
# Command:  view
# Three letter month:  july
# invalid month
# view	 -View sales for specified month
# edit	 -Edit sales for specified month
# totals	 -View sales summary for year
# exit	 -Exit program
# Command:  exit
# OKay bye bye!!!!!!!
